# %% [markdown]
# # PyPI package downloads monitor
#
# https://packaging.python.org/guides/analyzing-pypi-package-downloads/ (see also https://pepy.tech)

# %%
"""$ pip install pandas-gbq google-cloud-bigquery google-auth-oauthlib pycountry"""

# %matplotlib inline

import calendar
import datetime
import functools
import json
import logging
import pathlib

import numpy as np
import pandas as pd
import pycountry

PROJECT_ID = 'scripting-148608'

CRED_KW = {'token', 'refresh_token', 'id_token', 'token_uri', 'client_id', 'client_secret'}

DEBUG =  True

if DEBUG:
    log = logging.getLogger('pandas_gbq')
    log.setLevel(logging.DEBUG)
    log.addHandler(logging.StreamHandler())


def get_credentials(scopes=('https://www.googleapis.com/auth/bigquery',), 
                    secrets=pathlib.Path('~/client_secrets.json'),
                    storage=pathlib.Path('~/storage.json')):
    secrets, storage = (path.expanduser() for path in(secrets, storage))

    def make_credentials(filename, scopes):
        from google_auth_oauthlib.flow import InstalledAppFlow

        flow = InstalledAppFlow.from_client_secrets_file(filename, scopes)
        flow.run_local_server()
        return flow.credentials

    def load_credentials(filepath, scopes):
        from google.oauth2.credentials import Credentials

        with filepath.open('rb') as f:
            kwargs = json.load(f)
        kwargs['token'] = kwargs.pop('access_token')
        kwargs = {k: v for k, v in kwargs.items() if k in CRED_KW}
        return Credentials(scopes=scopes, **kwargs)

    def save_credentials(creds, filepath):
        doc = {k: getattr(creds, k) for k in (CRED_KW - {'token'})}
        doc['access_token'] = creds.token
        with filepath.open('w') as f:
            json.dump(doc, f)

    if storage.exists():
        creds = load_credentials(storage, scopes)
    else:
        creds = None
    if creds is None:
        creds = make_credentials(secrets, scopes)
        save_credentials(creds, storage)
    return creds


pd.set_option('display.max_rows', 100)
    

read_gbq = functools.partial(pd.read_gbq, project_id=PROJECT_ID,
                             credentials=get_credentials())

# %% [markdown]
# ## [bigquery-public-data.pypi.file_downloads](https://console.cloud.google.com/bigquery?pli=1&p=bigquery-public-data&d=pypi&t=file_downloads&page=table)

# %%
TABLE_NAME = 'pypi.file_downloads'

MONTH = (2022, 10)

START = datetime.date(*MONTH, day=1)

END = datetime.date(*MONTH, day=calendar.monthrange(*MONTH)[1])

RESULT = pathlib.Path('pypi_archive') / f"{TABLE_NAME}-{START.strftime('%Y-%m')}.csv"

ENCODING = 'utf-8'

PROJECTS = ('bitsets', 'concepts', 'csv23', 'current', 'dmengine',
            'features', 'fileconfig', 'graphviz', 'gsheets', 'latexpages',
            'treedb')

INDEX = ['period',
         'project', 'version', 'type',
         'country', 'python', 'system']

QUERY = fr'''
SELECT
  FORMAT_TIMESTAMP('%Y-%m', timestamp) AS period,
  project,
  file.version,
  file.type,
  country_code AS country,
  REGEXP_EXTRACT(details.python, r'^\d+\.\d+') AS python,
  details.system.name AS system,
  COUNT(*) AS downloads
FROM `bigquery-public-data.{TABLE_NAME}`
WHERE
  DATE(timestamp) BETWEEN DATE('{START.isoformat()}') AND DATE('{END.isoformat()}')
  AND project IN {PROJECTS!r}
GROUP BY {', '.join(INDEX)}
ORDER BY {', '.join(INDEX)}
'''.strip()


if not RESULT.exists():
    if not RESULT.parent.exists():
        RESULT.parent.mkdir()
    _rf = read_gbq(QUERY)
    _rf.to_csv(RESULT, index=False, encoding=ENCODING)

    assert (_rf['downloads'] > 0).all()

(RESULT.name, RESULT.stat().st_size)
# Out:
# Requesting query...
# Query running...
# Job ID: 4ed059bc-03c5-4cbf-a5ee-62ac5c99fbdb
# Query done.
# Processed: 16.0 GB Billed: 16.0 GB
# Standard price: $0.08 USD
#
# Got 16937 rows.
#
# Total time taken 16.03 s.
# Finished at 2022-11-06 10:53:02.
# ('pypi.file_downloads-2022-10.csv', 818739)

# %%
CSV_FORMAT = {'dtype': {'period': 'string',
                        'project': 'string',
                        'version': 'string',
                        'type': 'string',
                        'country': 'string',
                        'python': 'string',
                        'system': 'string',
                        'downloads': 'uint'},
              'na_values': '', 'keep_default_na': False,
              'encoding': ENCODING}


_rf = pd.read_csv(RESULT, **CSV_FORMAT)

_rf.info(memory_usage='deep')
assert _rf.set_index(INDEX).index.is_unique
assert _rf.sort_values(by=INDEX, na_position='first').equals(_rf)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16937 entries, 0 to 16936
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   period     16937 non-null  string
#  1   project    16937 non-null  string
#  2   version    16937 non-null  string
#  3   type       16937 non-null  string
#  4   country    16937 non-null  string
#  5   python     11909 non-null  string
#  6   system     11709 non-null  string
#  7   downloads  16937 non-null  uint32
# dtypes: string(7), uint32(1)
# memory usage: 7.0 MB

# %%
ARCHIVES = sorted(RESULT.parent.glob(f'{TABLE_NAME}-????-??.csv'))


_cf = pd.concat((pd.read_csv(p, **CSV_FORMAT) for p in ARCHIVES),
                ignore_index=True, copy=False)

_cf.info(memory_usage='deep')
assert _cf.set_index(INDEX).index.is_unique
assert _cf.sort_values(by=INDEX, na_position='first').equals(_cf)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855144 entries, 0 to 855143
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   period     855144 non-null  string
#  1   project    855144 non-null  string
#  2   version    855144 non-null  string
#  3   type       855144 non-null  string
#  4   country    815881 non-null  string
#  5   python     474019 non-null  string
#  6   system     444532 non-null  string
#  7   downloads  855144 non-null  uint32
# dtypes: string(7), uint32(1)
# memory usage: 344.1 MB

# %%
PROJECT = pd.CategoricalDtype(PROJECTS, ordered=True)

TYPE = pd.CategoricalDtype(['sdist', 'bdist_wheel'], ordered=True)

COUNTRY = pd.CategoricalDtype([c.alpha_2 for c in pycountry.countries], ordered=True)

PYTHON = pd.CategoricalDtype(['1.17',
                              '2.0', '2.1', '2.2', '2.3', '2.4', '2.5', '2.6', '2.7',
                              '3.0', '3.1', '3.2', '3.3', '3.4', '3.5', '3.6', '3.7', '3.8', '3.9', '3.10', '3.11',
                              '4.0',
                              'N/A'], ordered=True)

PYTHON_MAJOR = pd.CategoricalDtype(['1', '2', '3', '4'], ordered=True)

SYSTEM = pd.CategoricalDtype(['Linux', 'Windows', 'Darwin', 'FreeBSD', 'N/A'], ordered=True)

df = (_cf.assign(period=lambda x: pd.to_datetime(x['period']).dt.to_period(freq='M'))
      .set_index('period', drop=True)
      .fillna('N/A'))

VERSIONS = sorted(df['version'].unique(), key=lambda x: x.split('.'))


df['project'] = df['project'].astype(PROJECT)
df['version'] = df['version'].astype('category').cat.reorder_categories(VERSIONS, ordered=True)
df['type'] = df['type'].astype(TYPE)
df['country'] = df['country'].astype(COUNTRY)
df['python'] = df['python'].astype(PYTHON)
df['system'] = df['system'].astype(SYSTEM)

df.insert(df.columns.tolist().index('python') + 1,
          'python_major',
          df['python'].str.extract(r'^(\d+)', expand=False).astype(PYTHON_MAJOR))

# ignore treedb 0.0.6 downloads
assert df['downloads'].all()
df.loc[((df['project'] == 'treedb') & (df['version']  == '0.0.6')), 'downloads'] = 0
assert not df['downloads'].all()
assert df['downloads'].any()

df.info(memory_usage='deep')
#assert df.set_index([c for c in INDEX if c != 'period'], append=True).index.duplicated().sum() == 6738
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 855144 entries, 2016-05 to 2022-10
# Freq: M
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   project       855144 non-null  category
#  1   version       855144 non-null  category
#  2   type          855144 non-null  category
#  3   country       808339 non-null  category
#  4   python        855134 non-null  category
#  5   python_major  474009 non-null  category
#  6   system        852964 non-null  category
#  7   downloads     855144 non-null  uint32
# dtypes: category(7), uint32(1)
# memory usage: 17.2 MB
#          project version   type country python python_major system  downloads
# period
# 2016-05  bitsets     0.1  sdist      AU    N/A          NaN    N/A          1
# 2016-05  bitsets     0.1  sdist      CA    N/A          NaN    N/A          1
# 2016-05  bitsets     0.1  sdist      CN    N/A          NaN    N/A          4
# 2016-05  bitsets     0.1  sdist      CZ    N/A          NaN    N/A          1
# 2016-05  bitsets     0.1  sdist      DE    N/A          NaN    N/A          1

# %%
(df.describe(include='all')
 .fillna(0)
 .astype(int, errors='ignore')
 .replace(0, ''))
# Out:
#          project version         type country  python python_major  system  \
# count     855144  855144       855144  808339  855134       474009  852964
# unique        11     128            2     228      17            3       5
# top     graphviz   0.8.4  bdist_wheel      US     N/A            3     N/A
# freq      492218   51931       594198   62329  381125       398727  410612
# mean
# std
# min
# 25%
# 50%
# 75%
# max
#
#        downloads
# count     855144
# unique
# top
# freq
# mean         268
# std        11108
# min
# 25%            1
# 50%            2
# 75%            5
# max      2201709

# %%
(df.resample('Y')
 .agg({'downloads': ['sum',
                     'count', 'nunique', 'min', pd.Series.mode, 'median', 'max',
                     'mean', 'std',                     
                     'first', 'last']}))
# Out:
#        downloads                                                       \
#              sum   count nunique min mode median      max        mean
# period
# 2016      335323   37412     340   0    1    2.0     4694    8.962980
# 2017     1185394   74034     619   0    1    2.0    59500   16.011481
# 2018     3746626   91892     978   0    1    2.0   111462   40.772059
# 2019    13936296  134371    1719   0    1    2.0   253337  103.715058
# 2020    33732913  162403    2520   0    1    2.0   896057  207.711144
# 2021    78276899  183511    3134   1    1    2.0  1539371  426.551536
# 2022    98629185  171521    3295   0    1    2.0  2201709  575.026877
#
#
#                  std first last
# period
# 2016       73.018982     1    0
# 2017      419.026124     7    0
# 2018     1201.764917     4    0
# 2019     2763.576785     2   78
# 2020     6245.382454     3    1
# 2021    13772.912678     2   54
# 2022    19190.213818     1    1

# %%
(df.pivot_table(values='downloads', index='project', aggfunc='sum', margins=True)
 .assign(ratio=lambda x: x['downloads'] / x['downloads'].sum() * 2)
 .style.format({'downloads': '{:_d}', 'ratio': '{:.1%}'})
 .set_uuid('12'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12_level0_col0" class="col_heading level0 col0" >downloads</th>
#       <th id="T_12_level0_col1" class="col_heading level0 col1" >ratio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >project</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12_level0_row0" class="row_heading level0 row0" >bitsets</th>
#       <td id="T_12_row0_col0" class="data row0 col0" >375_172</td>
#       <td id="T_12_row0_col1" class="data row0 col1" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_12_level0_row1" class="row_heading level0 row1" >concepts</th>
#       <td id="T_12_row1_col0" class="data row1 col0" >351_672</td>
#       <td id="T_12_row1_col1" class="data row1 col1" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_12_level0_row2" class="row_heading level0 row2" >csv23</th>
#       <td id="T_12_row2_col0" class="data row2 col0" >554_718</td>
#       <td id="T_12_row2_col1" class="data row2 col1" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_12_level0_row3" class="row_heading level0 row3" >current</th>
#       <td id="T_12_row3_col0" class="data row3 col0" >71_364</td>
#       <td id="T_12_row3_col1" class="data row3 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_12_level0_row4" class="row_heading level0 row4" >dmengine</th>
#       <td id="T_12_row4_col0" class="data row4 col0" >86_489</td>
#       <td id="T_12_row4_col1" class="data row4 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_12_level0_row5" class="row_heading level0 row5" >features</th>
#       <td id="T_12_row5_col0" class="data row5 col0" >232_577</td>
#       <td id="T_12_row5_col1" class="data row5 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_12_level0_row6" class="row_heading level0 row6" >fileconfig</th>
#       <td id="T_12_row6_col0" class="data row6 col0" >224_592</td>
#       <td id="T_12_row6_col1" class="data row6 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_12_level0_row7" class="row_heading level0 row7" >graphviz</th>
#       <td id="T_12_row7_col0" class="data row7 col0" >225_159_987</td>
#       <td id="T_12_row7_col1" class="data row7 col1" >98.0%</td>
#     </tr>
#     <tr>
#       <th id="T_12_level0_row8" class="row_heading level0 row8" >gsheets</th>
#       <td id="T_12_row8_col0" class="data row8 col0" >2_566_140</td>
#       <td id="T_12_row8_col1" class="data row8 col1" >1.1%</td>
#     </tr>
#     <tr>
#       <th id="T_12_level0_row9" class="row_heading level0 row9" >latexpages</th>
#       <td id="T_12_row9_col0" class="data row9 col0" >129_483</td>
#       <td id="T_12_row9_col1" class="data row9 col1" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_12_level0_row10" class="row_heading level0 row10" >treedb</th>
#       <td id="T_12_row10_col0" class="data row10 col0" >90_442</td>
#       <td id="T_12_row10_col1" class="data row10 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_12_level0_row11" class="row_heading level0 row11" >All</th>
#       <td id="T_12_row11_col0" class="data row11 col0" >229_842_636</td>
#       <td id="T_12_row11_col1" class="data row11 col1" >100.0%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df
# 2020-09   2942627    15650        1636    2508
# 2020-10   3244330    17035        1325    1911
# 2020-11   3373476    16229        1492    2573
# 2020-12   3803641    16735        1523    2144
# 2021-01   4018108    17937        1445    2806
# 2021-02   4294690    28426        1386    1901
# 2021-03   5946853    38656        1674    3854
# 2021-04   5982045    53274        1242    2214
# 2021-05   5729524   103297        1223    2644
# 2021-06   5405157    58302        1161    2356
# 2021-07   5915651    70112        1271    2735
# 2021-08   6965486   103072        1258    1947
# 2021-09   7210738   151835        1148    1855
# 2021-10   7906683   165510         792    2046
# 2021-11   8804776   171764         752    1227
# 2021-12   8504817   214908        2040    1929
# 2022-01   8664390    76132        1410    2422
# 2022-02   8945951    76286        1328    2585
# 2022-03  10737133   103718        2545    3636
# 2022-04   9244758   104438        1385    3020
# 2022-05  11373270   110636         880    2159
# 2022-06   9922527   140429        1430    2097
# 2022-07   9394143   118080         976    1647
# 2022-08  10473358   152271        1143    1980
# 2022-09   9060356   158957        1052    2058
# 2022-10   9158391   131797        1288    2478

# %%
PLOT_FORMAT = {'figsize': (864 / 100, 288 / 100)}


(df.pivot_table(values='downloads', index='period', aggfunc='sum')
 .plot.area(**PLOT_FORMAT));

# %%
(df.pivot_table(values='downloads', index='period', columns='project', aggfunc='sum')
 .plot(logy=True, **PLOT_FORMAT));

# %%
(df.pivot_table(values='downloads', index='period', columns='project', aggfunc='sum')
 .cumsum().plot.area(**PLOT_FORMAT));

# %%
(df.pivot_table(values='downloads', index='period', columns='project', aggfunc='sum')
 .cumsum().plot(logy=True, **PLOT_FORMAT));

# %%
(df.pivot_table(values='downloads', index='python', aggfunc='sum', margins=True)
 [lambda x: x['downloads'] > 1_000]
 .sort_values(by='downloads', ascending=False)
 .assign(ratio=lambda x: x['downloads'] / x['downloads'].sum() * 2)
 .style.format({'downloads': '{:_d}', 'ratio': '{:.2%}'})
 .set_uuid('6'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6_level0_col0" class="col_heading level0 col0" >downloads</th>
#       <th id="T_6_level0_col1" class="col_heading level0 col1" >ratio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >python</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6_level0_row0" class="row_heading level0 row0" >All</th>
#       <td id="T_6_row0_col0" class="data row0 col0" >229_842_609</td>
#       <td id="T_6_row0_col1" class="data row0 col1" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6_level0_row1" class="row_heading level0 row1" >3.7</th>
#       <td id="T_6_row1_col0" class="data row1 col0" >90_848_757</td>
#       <td id="T_6_row1_col1" class="data row1 col1" >39.53%</td>
#     </tr>
#     <tr>
#       <th id="T_6_level0_row2" class="row_heading level0 row2" >3.8</th>
#       <td id="T_6_row2_col0" class="data row2 col0" >58_739_111</td>
#       <td id="T_6_row2_col1" class="data row2 col1" >25.56%</td>
#     </tr>
#     <tr>
#       <th id="T_6_level0_row3" class="row_heading level0 row3" >3.6</th>
#       <td id="T_6_row3_col0" class="data row3 col0" >33_051_305</td>
#       <td id="T_6_row3_col1" class="data row3 col1" >14.38%</td>
#     </tr>
#     <tr>
#       <th id="T_6_level0_row4" class="row_heading level0 row4" >2.7</th>
#       <td id="T_6_row4_col0" class="data row4 col0" >18_691_945</td>
#       <td id="T_6_row4_col1" class="data row4 col1" >8.13%</td>
#     </tr>
#     <tr>
#       <th id="T_6_level0_row5" class="row_heading level0 row5" >3.9</th>
#       <td id="T_6_row5_col0" class="data row5 col0" >13_715_342</td>
#       <td id="T_6_row5_col1" class="data row5 col1" >5.97%</td>
#     </tr>
#     <tr>
#       <th id="T_6_level0_row6" class="row_heading level0 row6" >N/A</th>
#       <td id="T_6_row6_col0" class="data row6 col0" >7_203_674</td>
#       <td id="T_6_row6_col1" class="data row6 col1" >3.13%</td>
#     </tr>
#     <tr>
#       <th id="T_6_level0_row7" class="row_heading level0 row7" >3.5</th>
#       <td id="T_6_row7_col0" class="data row7 col0" >5_807_236</td>
#       <td id="T_6_row7_col1" class="data row7 col1" >2.53%</td>
#     </tr>
#     <tr>
#       <th id="T_6_level0_row8" class="row_heading level0 row8" >3.10</th>
#       <td id="T_6_row8_col0" class="data row8 col0" >1_585_743</td>
#       <td id="T_6_row8_col1" class="data row8 col1" >0.69%</td>
#     </tr>
#     <tr>
#       <th id="T_6_level0_row9" class="row_heading level0 row9" >3.4</th>
#       <td id="T_6_row9_col0" class="data row9 col0" >177_021</td>
#       <td id="T_6_row9_col1" class="data row9 col1" >0.08%</td>
#     </tr>
#     <tr>
#       <th id="T_6_level0_row10" class="row_heading level0 row10" >2.6</th>
#       <td id="T_6_row10_col0" class="data row10 col0" >8_329</td>
#       <td id="T_6_row10_col1" class="data row10 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6_level0_row11" class="row_heading level0 row11" >3.11</th>
#       <td id="T_6_row11_col0" class="data row11 col0" >7_581</td>
#       <td id="T_6_row11_col1" class="data row11 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6_level0_row12" class="row_heading level0 row12" >3.3</th>
#       <td id="T_6_row12_col0" class="data row12 col0" >5_637</td>
#       <td id="T_6_row12_col1" class="data row12 col1" >0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
(df.pivot_table(values='downloads', index='python', aggfunc='sum')
 .sort_values(by='downloads', ascending=False)
 .head(10)
 .plot.bar(**PLOT_FORMAT));

# %%
(df.pivot_table(values='downloads', index='period', columns='python_major', aggfunc='sum')
 .stack(level='python_major')
 [lambda x: x > 1_000]
 .transform(lambda x: 100 * x / x.groupby(level='period').sum())
 .unstack(level='python_major')
 .plot(**PLOT_FORMAT));

# %%
(df.pivot_table(values='downloads', index='period', columns='python', aggfunc='sum')
 .stack(level='python')
 [lambda x: x > 1_000]
 .transform(lambda x: 100 * x / x.groupby(level='period').sum())
 .unstack(level='python')
 .sort_values(axis='columns', by='python')
 .plot.area(**PLOT_FORMAT));

# %%
(df.pivot_table(values='downloads', index='period', columns='python', aggfunc='sum')
 .drop('N/A', axis='columns')
 .stack(level='python')
 [lambda x: x > 1_000]
 .transform(lambda x: 100 * x / x.groupby(level='period').sum())
 .unstack(level='python')
 .plot.area(**PLOT_FORMAT));

# %%
(df.pivot_table(values='downloads', index='period', columns='country', aggfunc='sum')
 .stack(level='country')
 .groupby('country')
 .filter(lambda g: (g > 60_000).any())
 .transform(lambda x: 100 * x / x.groupby(level='period').sum())
 .sort_values(ascending=False)
 .unstack(level='country')
 .plot.area(**PLOT_FORMAT));

# %%
(df.pivot_table(values='downloads', index='period', columns='system', aggfunc='sum')
 .stack(level='system')
 .transform(lambda x: 100 * x / x.groupby(level='period').sum())
 .unstack(level='system')
 .plot.area(**PLOT_FORMAT));

# %%
(df.pivot_table(values='downloads', index='period', columns='system', aggfunc='sum')
 .drop('N/A', axis='columns')
 .stack(level='system')
 .transform(lambda x: 100 * x / x.groupby(level='period').sum())
 .unstack(level='system')
 .plot.area(**PLOT_FORMAT));

# %%
(df.pivot_table(values='downloads', index='period', columns='type', aggfunc='sum')
 .stack(level='type')
 .transform(lambda x: 100 * x / x.groupby(level='period').sum())
 .unstack(level='type')
 .plot.area(**PLOT_FORMAT));

# %%
(df[df['project'] == 'graphviz']
 .pivot_table(values='downloads', index='version', aggfunc='sum')
 .sort_values(by='downloads', ascending=False)
 .head(20)
 .plot.bar(**PLOT_FORMAT));

# %%
for _, yf in df[lambda x: x['project'] == 'graphviz'].groupby(pd.Grouper(freq='Y')):
    (yf.pivot_table(values='downloads', index='period', columns='version', aggfunc='sum')
     [lambda x: x.sum().sort_values(ascending=False).cumsum()[lambda x: x / x.iat[-1] <= .85].index.tolist()]
     .plot.area(**PLOT_FORMAT))

# %%
(df[(df['project'] == 'graphviz')]
 .reset_index(level='period')
 .groupby('version')
 .agg({'period': 'first', 'downloads': 'sum'})
 .assign(ratio=lambda x: (x['downloads'] / x['downloads'].sum() * 2).map('{:.1%}'.format))
 .reset_index()
 .dropna()
 .set_index('period')
 .sort_values(by=['period', 'version'])
 ['2016-06':])
# Out:
#         version  downloads  ratio
# period
# 2016-09     0.5      10574   0.0%
# 2016-09   0.5.1     176962   0.2%
# 2016-12   0.5.2     220051   0.2%
# 2017-03     0.6     143607   0.1%
# 2017-04     0.7      67547   0.1%
# 2017-05   0.7.1     202826   0.2%
# 2017-07     0.8     552895   0.5%
# 2017-10   0.8.1     920453   0.8%
# 2017-12   0.8.2    4197668   3.7%
# 2018-04   0.8.3     415924   0.4%
# 2018-07   0.8.4   21958264  19.5%
# 2018-08     0.9    4304556   3.8%
# 2018-10    0.10      29226   0.0%
# 2018-10  0.10.1    5268580   4.7%
# 2019-06    0.11    1513313   1.3%
# 2019-07  0.11.1    1201138   1.1%
# 2019-08    0.12     713705   0.6%
# 2019-09    0.13    2088852   1.9%
# 2019-11  0.13.1      62493   0.1%
# 2019-11  0.13.2   12810282  11.4%
# 2020-04    0.14   12299768  10.9%
# 2020-07  0.14.1    8208379   7.3%
# 2020-10  0.14.2    3873901   3.4%
# 2020-11    0.15    3767487   3.3%
# 2020-12    0.16   45593410  40.5%
# 2021-07    0.17   23570927  20.9%
# 2021-11    0.18    1881859   1.7%
# 2021-11  0.18.1     267026   0.2%
# 2021-11  0.18.2    2684678   2.4%
# 2021-11    0.19    3361828   3.0%
# 2021-12  0.19.1   24739987  22.0%
# 2022-04  0.19.2    1568061   1.4%
# 2022-04    0.20   18004984  16.0%
# 2022-07  0.20.1   17118099  15.2%
